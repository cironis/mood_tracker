# %%
from auxiliar.google_sheets import get_sheet_data,append_sheet_data

base_mood = get_sheet_data("mood_base")

# %%
base_mood
# Out:
#          data             incomodo                            observacao  \
# 0  05/03/2026       Dor na costela  Machuquei a costela esquerda no Jiu.
# 1  06/03/2026       Dor na costela           Não consegui dormir direito
# 2  07/03/2026       Dor na costela                                Passou
# 3  05/03/2026  Cachorro do vizinho  Machuquei a costela esquerda no Jiu.
# 4  06/03/2026  Cachorro do vizinho           Não consegui dormir direito
# 5  07/03/2026  Cachorro do vizinho                                Passou
# 6  07/03/2026       Dor na costela                                Passou
#
#   intensidade
# 0           4
# 1           3
# 2           2
# 3           4
# 4           3
# 5           2
# 6           2

# %%
from auxiliar.tratar_bases import pegar_moods_nao_resolvidos

pegar_moods_nao_resolvidos(base_mood)
# Out:
#               incomodo observacao intensidade
# 1  Cachorro do vizinho     Passou           2
# 2       Dor na costela     Passou           2
